# %%
import os
import katdal
import katpoint
# %pylab inline
import scape
import string
import time
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: PyFITS was not found - FITS creation will be disabled

# %%
name = '1657099540' #'1607433065'  # e.g 1583650035
file_=str('http://archive-gw-1.kat.ac.za:7480/'+name+'/'+name+'_sdp_l0.full.rdb')
rdb=katdal.open(file_)
print(rdb)
# Out:
# DEBUG: Starting new HTTP connection (1): archive-gw-1.kat.ac.za:7480
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540/1657099540_sdp_l0.full.rdb HTTP/1.1" 200 183153
# DEBUG: Loading data from RDB dump of unknown bytes
# INFO: Loading 137 keys from <_io.BytesIO object at 0x7f0995423780>
# INFO: Using capture block '1657099540' and stream 'sdp_l0'
# DEBUG: label 0:
#     vis = arg(0, name=vis)                   ['vis']
#     weights = arg(1, name=weights)           ['weights']
#     auto_indices = arg(2, name=auto_indices) ['auto_indices']
#     index1 = arg(3, name=index1)             ['index1']
#     index2 = arg(4, name=index2)             ['index2']
#     out = arg(5, name=out)                   ['out']
#     divide = arg(6, name=divide)             ['divide']
#     $0.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>) ['$0.1']
#     $0.2 = getattr(value=$0.1, attr=empty)   ['$0.1', '$0.2']
#     $0.3 = global(len: <built-in function len>) ['$0.3']
#     $0.5 = call $0.3(auto_indices, func=$0.3, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None) ['$0.3', '$0.5', 'auto_indices']
#     $0.6 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>) ['$0.6']
#     $0.7 = getattr(value=$0.6, attr=float32) ['$0.6', '$0.7']
#     $0.8 = call $0.2($0.5, $0.7, func=$0.2, args=[Var($0.5, vis_flags_weights.py:184), Var($0.7, vis_flags_weights.py:184)], kws=(), vararg=None) ['$0.2', '$0.5', '$0.7', '$0.8']
#     auto_scale = $0.8                        ['$0.8', 'auto_scale']
#     $const0.10 = const(NoneType, None)       ['$const0.10']
#     $0.11 = out is $const0.10                ['$0.11', '$const0.10', 'out']
#     bool26 = global(bool: <class 'bool'>)    ['bool26']
#     $26pred = call bool26($0.11, func=bool26, args=(Var($0.11, vis_flags_weights.py:185),), kws=(), vararg=None) ['$0.11', '$26pred', 'bool26']
#     branch $26pred, 28, 44                   ['$26pred']
# label 28:
#     $28.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>) ['$28.1']
#     $28.2 = getattr(value=$28.1, attr=empty) ['$28.1', '$28.2']
#     $28.4 = getattr(value=vis, attr=shape)   ['$28.4', 'vis']
#     $28.5 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>) ['$28.5']
#     $28.6 = getattr(value=$28.5, attr=float32) ['$28.5', '$28.6']
#     $28.7 = call $28.2($28.4, $28.6, func=$28.2, args=[Var($28.4, vis_flags_weights.py:185), Var($28.6, vis_flags_weights.py:185)], kws=(), vararg=None) ['$28.2', '$28.4', '$28.6', '$28.7']
#     $phi46.1 = $28.7                         ['$28.7', '$phi46.1']
#     jump 46                                  []
# label 44:
#     $phi46.1 = out                           ['$phi46.1', 'out']
#     jump 46                                  []
# label 46:
#     out.1 = $phi46.1                         ['$phi46.1', 'out.1']
#     $46.2 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>) ['$46.2']
#     $46.3 = getattr(value=$46.2, attr=float32) ['$46.2', '$46.3']
#     $const46.4 = const(float, 2.3283064365386963e-10) ['$const46.4']
#     $46.5 = call $46.3($const46.4, func=$46.3, args=[Var($const46.4, vis_flags_weights.py:186)], kws=(), vararg=None) ['$46.3', '$46.5', '$const46.4']
#     bad_weight = $46.5                       ['$46.5', 'bad_weight']
#     jump 58                                  []
# label 58:
#     jump 60                                  []
# label 60:
#     $60.1 = global(range: <class 'range'>)   ['$60.1']
#     $60.3 = getattr(value=vis, attr=shape)   ['$60.3', 'vis']
#     $const60.4 = const(int, 0)               ['$const60.4']
#     $60.5 = getitem(value=$60.3, index=$const60.4) ['$60.3', '$60.5', '$const60.4']
#     $60.6 = call $60.1($60.5, func=$60.1, args=[Var($60.5, vis_flags_weights.py:187)], kws=(), vararg=None) ['$60.1', '$60.5', '$60.6']
#     $60.7 = getiter(value=$60.6)             ['$60.6', '$60.7']
#     $phi74.1 = $60.7                         ['$60.7', '$phi74.1']
#     jump 74                                  []
# label 74:
#     $74.2 = iternext(value=$phi74.1)         ['$74.2', '$phi74.1']
#     $74.3 = pair_first(value=$74.2)          ['$74.2', '$74.3']
#     $74.4 = pair_second(value=$74.2)         ['$74.2', '$74.4']
#     $phi76.1 = $74.3                         ['$74.3', '$phi76.1']
#     $phi258.1 = $74.3                        ['$74.3', '$phi258.1']
#     $phi258.2 = $phi74.1                     ['$phi258.2', '$phi74.1']
#     branch $74.4, 76, 258                    ['$74.4']
# label 76:
#     i = $phi76.1                             ['$phi76.1', 'i']
#     jump 78                                  []
# label 78:
#     jump 80                                  []
# label 80:
#     $80.1 = global(range: <class 'range'>)   ['$80.1']
#     $80.3 = getattr(value=vis, attr=shape)   ['$80.3', 'vis']
#     $const80.4 = const(int, 1)               ['$const80.4']
#     $80.5 = getitem(value=$80.3, index=$const80.4) ['$80.3', '$80.5', '$const80.4']
#     $80.6 = call $80.1($80.5, func=$80.1, args=[Var($80.5, vis_flags_weights.py:188)], kws=(), vararg=None) ['$80.1', '$80.5', '$80.6']
#     $80.7 = getiter(value=$80.6)             ['$80.6', '$80.7']
#     $phi94.1 = $80.7                         ['$80.7', '$phi94.1']
#     jump 94                                  []
# label 94:
#     $94.2 = iternext(value=$phi94.1)         ['$94.2', '$phi94.1']
#     $94.3 = pair_first(value=$94.2)          ['$94.2', '$94.3']
#     $94.4 = pair_second(value=$94.2)         ['$94.2', '$94.4']
#     $phi96.1 = $94.3                         ['$94.3', '$phi96.1']
#     $phi254.1 = $94.3                        ['$94.3', '$phi254.1']
#     $phi254.2 = $phi94.1                     ['$phi254.2', '$phi94.1']
#     branch $94.4, 96, 254                    ['$94.4']
# label 96:
#     j = $phi96.1                             ['$phi96.1', 'j']
#     jump 98                                  []
# label 98:
#     jump 100                                 []
# label 100:
#     $100.1 = global(range: <class 'range'>)  ['$100.1']
#     $100.2 = global(len: <built-in function len>) ['$100.2']
#     $100.4 = call $100.2(auto_indices, func=$100.2, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None) ['$100.2', '$100.4', 'auto_indices']
#     $100.5 = call $100.1($100.4, func=$100.1, args=[Var($100.4, vis_flags_weights.py:189)], kws=(), vararg=None) ['$100.1', '$100.4', '$100.5']
#     $100.6 = getiter(value=$100.5)           ['$100.5', '$100.6']
#     $phi112.1 = $100.6                       ['$100.6', '$phi112.1']
#     jump 112                                 []
# label 112:
#     $112.2 = iternext(value=$phi112.1)       ['$112.2', '$phi112.1']
#     $112.3 = pair_first(value=$112.2)        ['$112.2', '$112.3']
#     $112.4 = pair_second(value=$112.2)       ['$112.2', '$112.4']
#     $phi114.1 = $112.3                       ['$112.3', '$phi114.1']
#     $phi160.1 = $112.3                       ['$112.3', '$phi160.1']
#     $phi160.2 = $phi112.1                    ['$phi112.1', '$phi160.2']
#     branch $112.4, 114, 160                  ['$112.4']
# label 114:
#     k = $phi114.1                            ['$phi114.1', 'k']
#     $114.7 = getitem(value=auto_indices, index=k) ['$114.7', 'auto_indices', 'k']
#     $114.8 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var($114.7, vis_flags_weights.py:190)]) ['$114.7', '$114.8', 'i', 'j']
#     $114.9 = getitem(value=vis, index=$114.8) ['$114.8', '$114.9', 'vis']
#     $114.10 = getattr(value=$114.9, attr=real) ['$114.10', '$114.9']
#     autocorr = $114.10                       ['$114.10', 'autocorr']
#     bool138 = global(bool: <class 'bool'>)   ['bool138']
#     $138pred = call bool138(divide, func=bool138, args=(Var(divide, vis_flags_weights.py:184),), kws=(), vararg=None) ['$138pred', 'bool138', 'divide']
#     branch $138pred, 140, 150                ['$138pred']
# label 140:
#     $140.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>) ['$140.1']
#     $140.2 = getattr(value=$140.1, attr=reciprocal) ['$140.1', '$140.2']
#     $140.4 = call $140.2(autocorr, func=$140.2, args=[Var(autocorr, vis_flags_weights.py:190)], kws=(), vararg=None) ['$140.2', '$140.4', 'autocorr']
#     $phi152.3 = $140.4                       ['$140.4', '$phi152.3']
#     jump 152                                 []
# label 150:
#     $phi152.3 = autocorr                     ['$phi152.3', 'autocorr']
#     jump 152                                 []
# label 152:
#     auto_scale[k] = $phi152.3                ['$phi152.3', 'auto_scale', 'k']
#     jump 112                                 []
# label 160:
#     jump 162                                 []
# label 162:
#     jump 164                                 []
# label 164:
#     $164.1 = global(range: <class 'range'>)  ['$164.1']
#     $164.3 = getattr(value=vis, attr=shape)  ['$164.3', 'vis']
#     $const164.4 = const(int, 2)              ['$const164.4']
#     $164.5 = getitem(value=$164.3, index=$const164.4) ['$164.3', '$164.5', '$const164.4']
#     $164.6 = call $164.1($164.5, func=$164.1, args=[Var($164.5, vis_flags_weights.py:192)], kws=(), vararg=None) ['$164.1', '$164.5', '$164.6']
#     $164.7 = getiter(value=$164.6)           ['$164.6', '$164.7']
#     $phi178.1 = $164.7                       ['$164.7', '$phi178.1']
#     jump 178                                 []
# label 178:
#     $178.2 = iternext(value=$phi178.1)       ['$178.2', '$phi178.1']
#     $178.3 = pair_first(value=$178.2)        ['$178.2', '$178.3']
#     $178.4 = pair_second(value=$178.2)       ['$178.2', '$178.4']
#     $phi180.1 = $178.3                       ['$178.3', '$phi180.1']
#     $phi250.1 = $178.3                       ['$178.3', '$phi250.1']
#     $phi250.2 = $phi178.1                    ['$phi178.1', '$phi250.2']
#     branch $178.4, 180, 250                  ['$178.4']
# label 180:
#     k = $phi180.1                            ['$phi180.1', 'k']
#     $180.5 = getitem(value=index1, index=k)  ['$180.5', 'index1', 'k']
#     $180.6 = getitem(value=auto_scale, index=$180.5) ['$180.5', '$180.6', 'auto_scale']
#     $180.10 = getitem(value=index2, index=k) ['$180.10', 'index2', 'k']
#     $180.11 = getitem(value=auto_scale, index=$180.10) ['$180.10', '$180.11', 'auto_scale']
#     $180.12 = $180.6 * $180.11               ['$180.11', '$180.12', '$180.6']
#     p = $180.12                              ['$180.12', 'p']
#     $180.13 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>) ['$180.13']
#     $180.14 = getattr(value=$180.13, attr=isfinite) ['$180.13', '$180.14']
#     $180.16 = call $180.14(p, func=$180.14, args=[Var(p, vis_flags_weights.py:193)], kws=(), vararg=None) ['$180.14', '$180.16', 'p']
#     bool214 = global(bool: <class 'bool'>)   ['bool214']
#     $214pred = call bool214($180.16, func=bool214, args=(Var($180.16, vis_flags_weights.py:198),), kws=(), vararg=None) ['$180.16', '$214pred', 'bool214']
#     branch $214pred, 220, 216                ['$214pred']
# label 216:
#     p = bad_weight                           ['bad_weight', 'p']
#     jump 220                                 []
# label 220:
#     $220.6 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k, vis_flags_weights.py:189)]) ['$220.6', 'i', 'j', 'k']
#     $220.7 = getitem(value=weights, index=$220.6) ['$220.6', '$220.7', 'weights']
#     $220.8 = p * $220.7                      ['$220.7', '$220.8', 'p']
#     $220.13 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k, vis_flags_weights.py:189)]) ['$220.13', 'i', 'j', 'k']
#     out.1[$220.13] = $220.8                  ['$220.13', '$220.8', 'out.1']
#     jump 178                                 []
# label 250:
#     jump 252                                 []
# label 252:
#     jump 94                                  []
# label 254:
#     jump 256                                 []
# label 256:
#     jump 74                                  []
# label 258:
#     jump 260                                 []
# label 260:
#     $260.2 = cast(value=out.1)               ['$260.2', 'out.1']
#     return $260.2                            ['$260.2']
# DEBUG: ==== SSA block analysis pass on 0
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: vis = arg(0, name=vis)
# DEBUG: on stmt: weights = arg(1, name=weights)
# DEBUG: on stmt: auto_indices = arg(2, name=auto_indices)
# DEBUG: on stmt: index1 = arg(3, name=index1)
# DEBUG: on stmt: index2 = arg(4, name=index2)
# DEBUG: on stmt: out = arg(5, name=out)
# DEBUG: on stmt: divide = arg(6, name=divide)
# DEBUG: on stmt: $0.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.2 = getattr(value=$0.1, attr=empty)
# DEBUG: on stmt: $0.3 = global(len: <built-in function len>)
# DEBUG: on stmt: $0.5 = call $0.3(auto_indices, func=$0.3, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: $0.6 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.7 = getattr(value=$0.6, attr=float32)
# DEBUG: on stmt: $0.8 = call $0.2($0.5, $0.7, func=$0.2, args=[Var($0.5, vis_flags_weights.py:184), Var($0.7, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: auto_scale = $0.8
# DEBUG: on stmt: $const0.10 = const(NoneType, None)
# DEBUG: on stmt: $0.11 = const(int, 1)
# DEBUG: on stmt: bool26 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $26pred = call bool26($0.11, func=bool26, args=(Var($0.11, vis_flags_weights.py:185),), kws=(), vararg=None)
# DEBUG: on stmt: jump 28
# DEBUG: ==== SSA block analysis pass on 28
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $28.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.2 = getattr(value=$28.1, attr=empty)
# DEBUG: on stmt: $28.4 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $28.5 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.6 = getattr(value=$28.5, attr=float32)
# DEBUG: on stmt: $28.7 = call $28.2($28.4, $28.6, func=$28.2, args=[Var($28.4, vis_flags_weights.py:185), Var($28.6, vis_flags_weights.py:185)], kws=(), vararg=None)
# DEBUG: on stmt: $phi46.1 = $28.7
# DEBUG: on stmt: jump 46
# DEBUG: ==== SSA block analysis pass on 46
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: out.1 = $phi46.1
# DEBUG: on stmt: $46.2 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $46.3 = getattr(value=$46.2, attr=float32)
# DEBUG: on stmt: $const46.4 = const(float, 2.3283064365386963e-10)
# DEBUG: on stmt: $46.5 = call $46.3($const46.4, func=$46.3, args=[Var($const46.4, vis_flags_weights.py:186)], kws=(), vararg=None)
# DEBUG: on stmt: bad_weight = $46.5
# DEBUG: on stmt: jump 58
# DEBUG: ==== SSA block analysis pass on 58
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 60
# DEBUG: ==== SSA block analysis pass on 60
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $60.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $60.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const60.4 = const(int, 0)
# DEBUG: on stmt: $60.5 = static_getitem(value=$60.3, index=0, index_var=$const60.4)
# DEBUG: on stmt: $60.6 = call $60.1($60.5, func=$60.1, args=[Var($60.5, vis_flags_weights.py:187)], kws=(), vararg=None)
# DEBUG: on stmt: $60.7 = getiter(value=$60.6)
# DEBUG: on stmt: $phi74.1 = $60.7
# DEBUG: on stmt: jump 74
# DEBUG: ==== SSA block analysis pass on 74
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $74.2 = iternext(value=$phi74.1)
# DEBUG: on stmt: $74.3 = pair_first(value=$74.2)
# DEBUG: on stmt: $74.4 = pair_second(value=$74.2)
# DEBUG: on stmt: $phi76.1 = $74.3
# DEBUG: on stmt: $phi258.1 = $74.3
# DEBUG: on stmt: $phi258.2 = $phi74.1
# DEBUG: on stmt: branch $74.4, 76, 258
# DEBUG: ==== SSA block analysis pass on 76
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: i = $phi76.1
# DEBUG: on stmt: jump 78
# DEBUG: ==== SSA block analysis pass on 78
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 80
# DEBUG: ==== SSA block analysis pass on 80
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $80.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $80.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const80.4 = const(int, 1)
# DEBUG: on stmt: $80.5 = static_getitem(value=$80.3, index=1, index_var=$const80.4)
# DEBUG: on stmt: $80.6 = call $80.1($80.5, func=$80.1, args=[Var($80.5, vis_flags_weights.py:188)], kws=(), vararg=None)
# DEBUG: on stmt: $80.7 = getiter(value=$80.6)
# DEBUG: on stmt: $phi94.1 = $80.7
# DEBUG: on stmt: jump 94
# DEBUG: ==== SSA block analysis pass on 94
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $94.2 = iternext(value=$phi94.1)
# DEBUG: on stmt: $94.3 = pair_first(value=$94.2)
# DEBUG: on stmt: $94.4 = pair_second(value=$94.2)
# DEBUG: on stmt: $phi96.1 = $94.3
# DEBUG: on stmt: $phi254.1 = $94.3
# DEBUG: on stmt: $phi254.2 = $phi94.1
# DEBUG: on stmt: branch $94.4, 96, 254
# DEBUG: ==== SSA block analysis pass on 96
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: j = $phi96.1
# DEBUG: on stmt: jump 98
# DEBUG: ==== SSA block analysis pass on 98
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 100
# DEBUG: ==== SSA block analysis pass on 100
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $100.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $100.2 = global(len: <built-in function len>)
# DEBUG: on stmt: $100.4 = call $100.2(auto_indices, func=$100.2, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: $100.5 = call $100.1($100.4, func=$100.1, args=[Var($100.4, vis_flags_weights.py:189)], kws=(), vararg=None)
# DEBUG: on stmt: $100.6 = getiter(value=$100.5)
# DEBUG: on stmt: $phi112.1 = $100.6
# DEBUG: on stmt: jump 112
# DEBUG: ==== SSA block analysis pass on 112
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $112.2 = iternext(value=$phi112.1)
# DEBUG: on stmt: $112.3 = pair_first(value=$112.2)
# DEBUG: on stmt: $112.4 = pair_second(value=$112.2)
# DEBUG: on stmt: $phi114.1 = $112.3
# DEBUG: on stmt: $phi160.1 = $112.3
# DEBUG: on stmt: $phi160.2 = $phi112.1
# DEBUG: on stmt: branch $112.4, 114, 160
# DEBUG: ==== SSA block analysis pass on 114
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: k = $phi114.1
# DEBUG: on stmt: $114.7 = getitem(value=auto_indices, index=k)
# DEBUG: on stmt: $114.8 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var($114.7, vis_flags_weights.py:190)])
# DEBUG: on stmt: $114.9 = getitem(value=vis, index=$114.8)
# DEBUG: on stmt: $114.10 = getattr(value=$114.9, attr=real)
# DEBUG: on stmt: autocorr = $114.10
# DEBUG: on stmt: bool138 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $138pred = call bool138(divide, func=bool138, args=(Var(divide, vis_flags_weights.py:184),), kws=(), vararg=None)
# DEBUG: on stmt: branch $138pred, 140, 150
# DEBUG: ==== SSA block analysis pass on 140
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $140.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $140.2 = getattr(value=$140.1, attr=reciprocal)
# DEBUG: on stmt: $140.4 = call $140.2(autocorr, func=$140.2, args=[Var(autocorr, vis_flags_weights.py:190)], kws=(), vararg=None)
# DEBUG: on stmt: $phi152.3 = $140.4
# DEBUG: on stmt: jump 152
# DEBUG: ==== SSA block analysis pass on 150
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $phi152.3 = autocorr
# DEBUG: on stmt: jump 152
# DEBUG: ==== SSA block analysis pass on 152
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: auto_scale[k] = $phi152.3
# DEBUG: on stmt: jump 112
# DEBUG: ==== SSA block analysis pass on 160
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 162
# DEBUG: ==== SSA block analysis pass on 162
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 164
# DEBUG: ==== SSA block analysis pass on 164
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $164.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $164.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const164.4 = const(int, 2)
# DEBUG: on stmt: $164.5 = static_getitem(value=$164.3, index=2, index_var=$const164.4)
# DEBUG: on stmt: $164.6 = call $164.1($164.5, func=$164.1, args=[Var($164.5, vis_flags_weights.py:192)], kws=(), vararg=None)
# DEBUG: on stmt: $164.7 = getiter(value=$164.6)
# DEBUG: on stmt: $phi178.1 = $164.7
# DEBUG: on stmt: jump 178
# DEBUG: ==== SSA block analysis pass on 178
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $178.2 = iternext(value=$phi178.1)
# DEBUG: on stmt: $178.3 = pair_first(value=$178.2)
# DEBUG: on stmt: $178.4 = pair_second(value=$178.2)
# DEBUG: on stmt: $phi180.1 = $178.3
# DEBUG: on stmt: $phi250.1 = $178.3
# DEBUG: on stmt: $phi250.2 = $phi178.1
# DEBUG: on stmt: branch $178.4, 180, 250
# DEBUG: ==== SSA block analysis pass on 180
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: k = $phi180.1
# DEBUG: on stmt: $180.5 = getitem(value=index1, index=k)
# DEBUG: on stmt: $180.6 = getitem(value=auto_scale, index=$180.5)
# DEBUG: on stmt: $180.10 = getitem(value=index2, index=k)
# DEBUG: on stmt: $180.11 = getitem(value=auto_scale, index=$180.10)
# DEBUG: on stmt: $180.12 = $180.6 * $180.11
# DEBUG: on stmt: p = $180.12
# DEBUG: on stmt: $180.13 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $180.14 = getattr(value=$180.13, attr=isfinite)
# DEBUG: on stmt: $180.16 = call $180.14(p, func=$180.14, args=[Var(p, vis_flags_weights.py:193)], kws=(), vararg=None)
# DEBUG: on stmt: bool214 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $214pred = call bool214($180.16, func=bool214, args=(Var($180.16, vis_flags_weights.py:198),), kws=(), vararg=None)
# DEBUG: on stmt: branch $214pred, 220, 216
# DEBUG: ==== SSA block analysis pass on 216
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: p = bad_weight
# DEBUG: on stmt: jump 220
# DEBUG: ==== SSA block analysis pass on 220
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $220.6 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k, vis_flags_weights.py:189)])
# DEBUG: on stmt: $220.7 = getitem(value=weights, index=$220.6)
# DEBUG: on stmt: $220.8 = p * $220.7
# DEBUG: on stmt: $220.13 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k, vis_flags_weights.py:189)])
# DEBUG: on stmt: out.1[$220.13] = $220.8
# DEBUG: on stmt: jump 178
# DEBUG: ==== SSA block analysis pass on 250
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 252
# DEBUG: ==== SSA block analysis pass on 252
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 94
# DEBUG: ==== SSA block analysis pass on 254
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 256
# DEBUG: ==== SSA block analysis pass on 256
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 74
# DEBUG: ==== SSA block analysis pass on 258
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 260
# DEBUG: ==== SSA block analysis pass on 260
# DEBUG: Running <numba.core.ssa._GatherDefsHandler object at 0x7f099408b860>
# DEBUG: on stmt: $260.2 = cast(value=out.1)
# DEBUG: on stmt: return $260.2
# DEBUG: defs defaultdict(<class 'list'>,
#             {'$0.1': [<numba.core.ir.Assign object at 0x7f099407af98>],
#              '$0.11': [<numba.core.ir.Assign object at 0x7f099408b8d0>],
#              '$0.2': [<numba.core.ir.Assign object at 0x7f099408b0b8>],
#              '$0.3': [<numba.core.ir.Assign object at 0x7f099408b198>],
#              '$0.5': [<numba.core.ir.Assign object at 0x7f099408b320>],
#              '$0.6': [<numba.core.ir.Assign object at 0x7f099408b400>],
#              '$0.7': [<numba.core.ir.Assign object at 0x7f099408b4e0>],
#              '$0.8': [<numba.core.ir.Assign object at 0x7f099408b5c0>],
#              '$100.1': [<numba.core.ir.Assign object at 0x7f09940995c0>],
#              '$100.2': [<numba.core.ir.Assign object at 0x7f09940996a0>],
#              '$100.4': [<numba.core.ir.Assign object at 0x7f0994099828>],
#              '$100.5': [<numba.core.ir.Assign object at 0x7f0994099908>],
#              '$100.6': [<numba.core.ir.Assign object at 0x7f09940999e8>],
#              '$112.2': [<numba.core.ir.Assign object at 0x7f0994099ba8>],
#              '$112.3': [<numba.core.ir.Assign object at 0x7f0994099c50>],
#              '$112.4': [<numba.core.ir.Assign object at 0x7f0994099cf8>],
#              '$114.10': [<numba.core.ir.Assign object at 0x7f099409b6a0>],
#              '$114.7': [<numba.core.ir.Assign object at 0x7f099409b400>],
#              '$114.8': [<numba.core.ir.Assign object at 0x7f099409b4e0>],
#              '$114.9': [<numba.core.ir.Assign object at 0x7f099409b5c0>],
#              '$138pred': [<numba.core.ir.Assign object at 0x7f099409b9b0>],
#              '$140.1': [<numba.core.ir.Assign object at 0x7f099409b7f0>],
#              '$140.2': [<numba.core.ir.Assign object at 0x7f099409bac8>],
#              '$140.4': [<numba.core.ir.Assign object at 0x7f099409bc50>],
#              '$164.1': [<numba.core.ir.Assign object at 0x7f09940a2358>],
#              '$164.3': [<numba.core.ir.Assign object at 0x7f09940a24e0>],
#              '$164.5': [<numba.core.ir.Assign object at 0x7f099407a320>],
#              '$164.6': [<numba.core.ir.Assign object at 0x7f09940a2780>],
#              '$164.7': [<numba.core.ir.Assign object at 0x7f09940a2860>],
#              '$178.2': [<numba.core.ir.Assign object at 0x7f09940a2a20>],
#              '$178.3': [<numba.core.ir.Assign object at 0x7f09940a2ac8>],
#              '$178.4': [<numba.core.ir.Assign object at 0x7f09940a2b70>],
#              '$180.10': [<numba.core.ir.Assign object at 0x7f09940a74a8>],
#              '$180.11': [<numba.core.ir.Assign object at 0x7f09940a7588>],
#              '$180.12': [<numba.core.ir.Assign object at 0x7f09940a7668>],
#              '$180.13': [<numba.core.ir.Assign object at 0x7f09940a77f0>],
#              '$180.14': [<numba.core.ir.Assign object at 0x7f09940a78d0>],
#              '$180.16': [<numba.core.ir.Assign object at 0x7f09940a7a58>],
#              '$180.5': [<numba.core.ir.Assign object at 0x7f09940a70f0>],
#              '$180.6': [<numba.core.ir.Assign object at 0x7f09940a71d0>],
#              '$214pred': [<numba.core.ir.Assign object at 0x7f09940a7c18>],
#              '$220.13': [<numba.core.ir.Assign object at 0x7f09940ab668>],
#              '$220.6': [<numba.core.ir.Assign object at 0x7f09940ab128>],
#              '$220.7': [<numba.core.ir.Assign object at 0x7f09940ab208>],
#              '$220.8': [<numba.core.ir.Assign object at 0x7f09940ab2e8>],
#              '$260.2': [<numba.core.ir.Assign object at 0x7f09940aba58>],
#              '$26pred': [<numba.core.ir.Assign object at 0x7f099408bac8>],
#              '$28.1': [<numba.core.ir.Assign object at 0x7f099408bbe0>],
#              '$28.2': [<numba.core.ir.Assign object at 0x7f099408bcc0>],
#              '$28.4': [<numba.core.ir.Assign object at 0x7f099408be48>],
#              '$28.5': [<numba.core.ir.Assign object at 0x7f099408bf28>],
#              '$28.6': [<numba.core.ir.Assign object at 0x7f0994090048>],
#              '$28.7': [<numba.core.ir.Assign object at 0x7f0994090128>],
#              '$46.2': [<numba.core.ir.Assign object at 0x7f0994090550>],
#              '$46.3': [<numba.core.ir.Assign object at 0x7f0994090630>],
#              '$46.5': [<numba.core.ir.Assign object at 0x7f09940907f0>],
#              '$60.1': [<numba.core.ir.Assign object at 0x7f0994090b00>],
#              '$60.3': [<numba.core.ir.Assign object at 0x7f0994090c88>],
#              '$60.5': [<numba.core.ir.Assign object at 0x7f099406d6d8>],
#              '$60.6': [<numba.core.ir.Assign object at 0x7f0994090f28>],
#              '$60.7': [<numba.core.ir.Assign object at 0x7f0994095048>],
#              '$74.2': [<numba.core.ir.Assign object at 0x7f0994095208>],
#              '$74.3': [<numba.core.ir.Assign object at 0x7f09940952b0>],
#              '$74.4': [<numba.core.ir.Assign object at 0x7f0994095358>],
#              '$80.1': [<numba.core.ir.Assign object at 0x7f0994095860>],
#              '$80.3': [<numba.core.ir.Assign object at 0x7f09940959e8>],
#              '$80.5': [<numba.core.ir.Assign object at 0x7f099406d7f0>],
#              '$80.6': [<numba.core.ir.Assign object at 0x7f0994095c88>],
#              '$80.7': [<numba.core.ir.Assign object at 0x7f0994095d68>],
#              '$94.2': [<numba.core.ir.Assign object at 0x7f0994095f28>],
#              '$94.3': [<numba.core.ir.Assign object at 0x7f0994095fd0>],
#              '$94.4': [<numba.core.ir.Assign object at 0x7f09940990b8>],
#              '$const0.10': [<numba.core.ir.Assign object at 0x7f099408b7f0>],
#              '$const164.4': [<numba.core.ir.Assign object at 0x7f09940a25c0>],
#              '$const46.4': [<numba.core.ir.Assign object at 0x7f0994090710>],
#              '$const60.4': [<numba.core.ir.Assign object at 0x7f0994090d68>],
#              '$const80.4': [<numba.core.ir.Assign object at 0x7f0994095ac8>],
#              '$phi112.1': [<numba.core.ir.Assign object at 0x7f0994099400>],
#              '$phi114.1': [<numba.core.ir.Assign object at 0x7f0994099d68>],
#              '$phi152.3': [<numba.core.ir.Assign object at 0x7f099409bb70>,
#                            <numba.core.ir.Assign object at 0x7f099409be10>],
#              '$phi160.1': [<numba.core.ir.Assign object at 0x7f0994099dd8>],
#              '$phi160.2': [<numba.core.ir.Assign object at 0x7f0994099e48>],
#              '$phi178.1': [<numba.core.ir.Assign object at 0x7f09940a2198>],
#              '$phi180.1': [<numba.core.ir.Assign object at 0x7f09940a2be0>],
#              '$phi250.1': [<numba.core.ir.Assign object at 0x7f09940a2c50>],
#              '$phi250.2': [<numba.core.ir.Assign object at 0x7f09940a2cc0>],
#              '$phi254.1': [<numba.core.ir.Assign object at 0x7f0994099198>],
#              '$phi254.2': [<numba.core.ir.Assign object at 0x7f0994099208>],
#              '$phi258.1': [<numba.core.ir.Assign object at 0x7f0994095438>],
#              '$phi258.2': [<numba.core.ir.Assign object at 0x7f09940954a8>],
#              '$phi46.1': [<numba.core.ir.Assign object at 0x7f099407a9e8>],
#              '$phi74.1': [<numba.core.ir.Assign object at 0x7f0994090940>],
#              '$phi76.1': [<numba.core.ir.Assign object at 0x7f09940953c8>],
#              '$phi94.1': [<numba.core.ir.Assign object at 0x7f09940956a0>],
#              '$phi96.1': [<numba.core.ir.Assign object at 0x7f0994099128>],
#              'auto_indices': [<numba.core.ir.Assign object at 0x7f099407ac18>],
#              'auto_scale': [<numba.core.ir.Assign object at 0x7f099408b668>],
#              'autocorr': [<numba.core.ir.Assign object at 0x7f099409b748>],
#              'bad_weight': [<numba.core.ir.Assign object at 0x7f0994090898>],
#              'bool138': [<numba.core.ir.Assign object at 0x7f099409b908>],
#              'bool214': [<numba.core.ir.Assign object at 0x7f09940a7b70>],
#              'bool26': [<numba.core.ir.Assign object at 0x7f099408b9e8>],
#              'divide': [<numba.core.ir.Assign object at 0x7f099407aeb8>],
#              'i': [<numba.core.ir.Assign object at 0x7f09940955f8>],
#              'index1': [<numba.core.ir.Assign object at 0x7f099407acc0>],
#              'index2': [<numba.core.ir.Assign object at 0x7f099407ad68>],
#              'j': [<numba.core.ir.Assign object at 0x7f0994099358>],
#              'k': [<numba.core.ir.Assign object at 0x7f0994099f98>,
#                    <numba.core.ir.Assign object at 0x7f09940a2dd8>],
#              'out': [<numba.core.ir.Assign object at 0x7f099407ae10>],
#              'out.1': [<numba.core.ir.Assign object at 0x7f0994090470>],
#              'p': [<numba.core.ir.Assign object at 0x7f09940a7710>,
#                    <numba.core.ir.Assign object at 0x7f09940a7978>],
#              'vis': [<numba.core.ir.Assign object at 0x7f099407aac8>],
#              'weights': [<numba.core.ir.Assign object at 0x7f099407ab70>]})
# DEBUG: SSA violators {'$phi152.3', 'k', 'p'}
# DEBUG: Fix SSA violator on var $phi152.3
# DEBUG: ==== SSA block rewrite pass on 0
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: vis = arg(0, name=vis)
# DEBUG: on stmt: weights = arg(1, name=weights)
# DEBUG: on stmt: auto_indices = arg(2, name=auto_indices)
# DEBUG: on stmt: index1 = arg(3, name=index1)
# DEBUG: on stmt: index2 = arg(4, name=index2)
# DEBUG: on stmt: out = arg(5, name=out)
# DEBUG: on stmt: divide = arg(6, name=divide)
# DEBUG: on stmt: $0.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.2 = getattr(value=$0.1, attr=empty)
# DEBUG: on stmt: $0.3 = global(len: <built-in function len>)
# DEBUG: on stmt: $0.5 = call $0.3(auto_indices, func=$0.3, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: $0.6 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.7 = getattr(value=$0.6, attr=float32)
# DEBUG: on stmt: $0.8 = call $0.2($0.5, $0.7, func=$0.2, args=[Var($0.5, vis_flags_weights.py:184), Var($0.7, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: auto_scale = $0.8
# DEBUG: on stmt: $const0.10 = const(NoneType, None)
# DEBUG: on stmt: $0.11 = const(int, 1)
# DEBUG: on stmt: bool26 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $26pred = call bool26($0.11, func=bool26, args=(Var($0.11, vis_flags_weights.py:185),), kws=(), vararg=None)
# DEBUG: on stmt: jump 28
# DEBUG: ==== SSA block rewrite pass on 28
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $28.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.2 = getattr(value=$28.1, attr=empty)
# DEBUG: on stmt: $28.4 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $28.5 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.6 = getattr(value=$28.5, attr=float32)
# DEBUG: on stmt: $28.7 = call $28.2($28.4, $28.6, func=$28.2, args=[Var($28.4, vis_flags_weights.py:185), Var($28.6, vis_flags_weights.py:185)], kws=(), vararg=None)
# DEBUG: on stmt: $phi46.1 = $28.7
# DEBUG: on stmt: jump 46
# DEBUG: ==== SSA block rewrite pass on 46
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: out.1 = $phi46.1
# DEBUG: on stmt: $46.2 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $46.3 = getattr(value=$46.2, attr=float32)
# DEBUG: on stmt: $const46.4 = const(float, 2.3283064365386963e-10)
# DEBUG: on stmt: $46.5 = call $46.3($const46.4, func=$46.3, args=[Var($const46.4, vis_flags_weights.py:186)], kws=(), vararg=None)
# DEBUG: on stmt: bad_weight = $46.5
# DEBUG: on stmt: jump 58
# DEBUG: ==== SSA block rewrite pass on 58
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 60
# DEBUG: ==== SSA block rewrite pass on 60
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $60.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $60.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const60.4 = const(int, 0)
# DEBUG: on stmt: $60.5 = static_getitem(value=$60.3, index=0, index_var=$const60.4)
# DEBUG: on stmt: $60.6 = call $60.1($60.5, func=$60.1, args=[Var($60.5, vis_flags_weights.py:187)], kws=(), vararg=None)
# DEBUG: on stmt: $60.7 = getiter(value=$60.6)
# DEBUG: on stmt: $phi74.1 = $60.7
# DEBUG: on stmt: jump 74
# DEBUG: ==== SSA block rewrite pass on 74
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $74.2 = iternext(value=$phi74.1)
# DEBUG: on stmt: $74.3 = pair_first(value=$74.2)
# DEBUG: on stmt: $74.4 = pair_second(value=$74.2)
# DEBUG: on stmt: $phi76.1 = $74.3
# DEBUG: on stmt: $phi258.1 = $74.3
# DEBUG: on stmt: $phi258.2 = $phi74.1
# DEBUG: on stmt: branch $74.4, 76, 258
# DEBUG: ==== SSA block rewrite pass on 76
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: i = $phi76.1
# DEBUG: on stmt: jump 78
# DEBUG: ==== SSA block rewrite pass on 78
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 80
# DEBUG: ==== SSA block rewrite pass on 80
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $80.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $80.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const80.4 = const(int, 1)
# DEBUG: on stmt: $80.5 = static_getitem(value=$80.3, index=1, index_var=$const80.4)
# DEBUG: on stmt: $80.6 = call $80.1($80.5, func=$80.1, args=[Var($80.5, vis_flags_weights.py:188)], kws=(), vararg=None)
# DEBUG: on stmt: $80.7 = getiter(value=$80.6)
# DEBUG: on stmt: $phi94.1 = $80.7
# DEBUG: on stmt: jump 94
# DEBUG: ==== SSA block rewrite pass on 94
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $94.2 = iternext(value=$phi94.1)
# DEBUG: on stmt: $94.3 = pair_first(value=$94.2)
# DEBUG: on stmt: $94.4 = pair_second(value=$94.2)
# DEBUG: on stmt: $phi96.1 = $94.3
# DEBUG: on stmt: $phi254.1 = $94.3
# DEBUG: on stmt: $phi254.2 = $phi94.1
# DEBUG: on stmt: branch $94.4, 96, 254
# DEBUG: ==== SSA block rewrite pass on 96
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: j = $phi96.1
# DEBUG: on stmt: jump 98
# DEBUG: ==== SSA block rewrite pass on 98
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 100
# DEBUG: ==== SSA block rewrite pass on 100
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $100.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $100.2 = global(len: <built-in function len>)
# DEBUG: on stmt: $100.4 = call $100.2(auto_indices, func=$100.2, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: $100.5 = call $100.1($100.4, func=$100.1, args=[Var($100.4, vis_flags_weights.py:189)], kws=(), vararg=None)
# DEBUG: on stmt: $100.6 = getiter(value=$100.5)
# DEBUG: on stmt: $phi112.1 = $100.6
# DEBUG: on stmt: jump 112
# DEBUG: ==== SSA block rewrite pass on 112
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $112.2 = iternext(value=$phi112.1)
# DEBUG: on stmt: $112.3 = pair_first(value=$112.2)
# DEBUG: on stmt: $112.4 = pair_second(value=$112.2)
# DEBUG: on stmt: $phi114.1 = $112.3
# DEBUG: on stmt: $phi160.1 = $112.3
# DEBUG: on stmt: $phi160.2 = $phi112.1
# DEBUG: on stmt: branch $112.4, 114, 160
# DEBUG: ==== SSA block rewrite pass on 114
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: k = $phi114.1
# DEBUG: on stmt: $114.7 = getitem(value=auto_indices, index=k)
# DEBUG: on stmt: $114.8 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var($114.7, vis_flags_weights.py:190)])
# DEBUG: on stmt: $114.9 = getitem(value=vis, index=$114.8)
# DEBUG: on stmt: $114.10 = getattr(value=$114.9, attr=real)
# DEBUG: on stmt: autocorr = $114.10
# DEBUG: on stmt: bool138 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $138pred = call bool138(divide, func=bool138, args=(Var(divide, vis_flags_weights.py:184),), kws=(), vararg=None)
# DEBUG: on stmt: branch $138pred, 140, 150
# DEBUG: ==== SSA block rewrite pass on 140
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $140.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $140.2 = getattr(value=$140.1, attr=reciprocal)
# DEBUG: on stmt: $140.4 = call $140.2(autocorr, func=$140.2, args=[Var(autocorr, vis_flags_weights.py:190)], kws=(), vararg=None)
# DEBUG: on stmt: $phi152.3 = $140.4
# DEBUG: first assign: $phi152.3
# DEBUG: replaced with: $phi152.3 = $140.4
# DEBUG: on stmt: jump 152
# DEBUG: ==== SSA block rewrite pass on 150
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $phi152.3 = autocorr
# DEBUG: replaced with: $phi152.3.1 = autocorr
# DEBUG: on stmt: jump 152
# DEBUG: ==== SSA block rewrite pass on 152
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: auto_scale[k] = $phi152.3
# DEBUG: on stmt: jump 112
# DEBUG: ==== SSA block rewrite pass on 160
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 162
# DEBUG: ==== SSA block rewrite pass on 162
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 164
# DEBUG: ==== SSA block rewrite pass on 164
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $164.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $164.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const164.4 = const(int, 2)
# DEBUG: on stmt: $164.5 = static_getitem(value=$164.3, index=2, index_var=$const164.4)
# DEBUG: on stmt: $164.6 = call $164.1($164.5, func=$164.1, args=[Var($164.5, vis_flags_weights.py:192)], kws=(), vararg=None)
# DEBUG: on stmt: $164.7 = getiter(value=$164.6)
# DEBUG: on stmt: $phi178.1 = $164.7
# DEBUG: on stmt: jump 178
# DEBUG: ==== SSA block rewrite pass on 178
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $178.2 = iternext(value=$phi178.1)
# DEBUG: on stmt: $178.3 = pair_first(value=$178.2)
# DEBUG: on stmt: $178.4 = pair_second(value=$178.2)
# DEBUG: on stmt: $phi180.1 = $178.3
# DEBUG: on stmt: $phi250.1 = $178.3
# DEBUG: on stmt: $phi250.2 = $phi178.1
# DEBUG: on stmt: branch $178.4, 180, 250
# DEBUG: ==== SSA block rewrite pass on 180
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: k = $phi180.1
# DEBUG: on stmt: $180.5 = getitem(value=index1, index=k)
# DEBUG: on stmt: $180.6 = getitem(value=auto_scale, index=$180.5)
# DEBUG: on stmt: $180.10 = getitem(value=index2, index=k)
# DEBUG: on stmt: $180.11 = getitem(value=auto_scale, index=$180.10)
# DEBUG: on stmt: $180.12 = $180.6 * $180.11
# DEBUG: on stmt: p = $180.12
# DEBUG: on stmt: $180.13 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $180.14 = getattr(value=$180.13, attr=isfinite)
# DEBUG: on stmt: $180.16 = call $180.14(p, func=$180.14, args=[Var(p, vis_flags_weights.py:193)], kws=(), vararg=None)
# DEBUG: on stmt: bool214 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $214pred = call bool214($180.16, func=bool214, args=(Var($180.16, vis_flags_weights.py:198),), kws=(), vararg=None)
# DEBUG: on stmt: branch $214pred, 220, 216
# DEBUG: ==== SSA block rewrite pass on 216
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: p = bad_weight
# DEBUG: on stmt: jump 220
# DEBUG: ==== SSA block rewrite pass on 220
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $220.6 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k, vis_flags_weights.py:189)])
# DEBUG: on stmt: $220.7 = getitem(value=weights, index=$220.6)
# DEBUG: on stmt: $220.8 = p * $220.7
# DEBUG: on stmt: $220.13 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k, vis_flags_weights.py:189)])
# DEBUG: on stmt: out.1[$220.13] = $220.8
# DEBUG: on stmt: jump 178
# DEBUG: ==== SSA block rewrite pass on 250
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 252
# DEBUG: ==== SSA block rewrite pass on 252
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 94
# DEBUG: ==== SSA block rewrite pass on 254
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 256
# DEBUG: ==== SSA block rewrite pass on 256
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 74
# DEBUG: ==== SSA block rewrite pass on 258
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 260
# DEBUG: ==== SSA block rewrite pass on 260
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $260.2 = cast(value=out.1)
# DEBUG: on stmt: return $260.2
# DEBUG: Replaced assignments: defaultdict(<class 'list'>,
#             {140: [<numba.core.ir.Assign object at 0x7f0994026b38>],
#              150: [<numba.core.ir.Assign object at 0x7f0994026dd8>]})
# DEBUG: ==== SSA block rewrite pass on 0
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf400>
# DEBUG: on stmt: vis = arg(0, name=vis)
# DEBUG: on stmt: weights = arg(1, name=weights)
# DEBUG: on stmt: auto_indices = arg(2, name=auto_indices)
# DEBUG: on stmt: index1 = arg(3, name=index1)
# DEBUG: on stmt: index2 = arg(4, name=index2)
# DEBUG: on stmt: out = arg(5, name=out)
# DEBUG: on stmt: divide = arg(6, name=divide)
# DEBUG: on stmt: $0.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.2 = getattr(value=$0.1, attr=empty)
# DEBUG: on stmt: $0.3 = global(len: <built-in function len>)
# DEBUG: on stmt: $0.5 = call $0.3(auto_indices, func=$0.3, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: $0.6 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.7 = getattr(value=$0.6, attr=float32)
# DEBUG: on stmt: $0.8 = call $0.2($0.5, $0.7, func=$0.2, args=[Var($0.5, vis_flags_weights.py:184), Var($0.7, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: auto_scale = $0.8
# DEBUG: on stmt: $const0.10 = const(NoneType, None)
# DEBUG: on stmt: $0.11 = const(int, 1)
# DEBUG: on stmt: bool26 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $26pred = call bool26($0.11, func=bool26, args=(Var($0.11, vis_flags_weights.py:185),), kws=(), vararg=None)
# DEBUG: on stmt: jump 28
# DEBUG: ==== SSA block rewrite pass on 28
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf400>
# DEBUG: on stmt: $28.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.2 = getattr(value=$28.1, attr=empty)
# DEBUG: on stmt: $28.4 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $28.5 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.6 = getattr(value=$28.5, attr=float32)
# DEBUG: on stmt: $28.7 = call $28.2($28.4, $28.6, func=$28.2, args=[Var($28.4, vis_flags_weights.py:185), Var($28.6, vis_flags_weights.py:185)], kws=(), vararg=None)
# DEBUG: on stmt: $phi46.1 = $28.7
# DEBUG: on stmt: jump 46
# DEBUG: ==== SSA block rewrite pass on 46
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf400>
# DEBUG: on stmt: out.1 = $phi46.1
# ...
# DEBUG: on stmt: $220.6 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k.1, vis_flags_weights.py:192)])
# DEBUG: on stmt: $220.7 = getitem(value=weights, index=$220.6)
# DEBUG: on stmt: $220.8 = p * $220.7
# DEBUG: on stmt: $220.13 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k.1, vis_flags_weights.py:192)])
# DEBUG: on stmt: out.1[$220.13] = $220.8
# DEBUG: on stmt: jump 178
# DEBUG: ==== SSA block rewrite pass on 250
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 252
# DEBUG: ==== SSA block rewrite pass on 252
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 94
# DEBUG: ==== SSA block rewrite pass on 254
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 256
# DEBUG: ==== SSA block rewrite pass on 256
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 74
# DEBUG: ==== SSA block rewrite pass on 258
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: jump 260
# DEBUG: ==== SSA block rewrite pass on 260
# DEBUG: Running <numba.core.ssa._FreshVarHandler object at 0x7f099408b860>
# DEBUG: on stmt: $260.2 = cast(value=out.1)
# DEBUG: on stmt: return $260.2
# DEBUG: Replaced assignments: defaultdict(<class 'list'>,
#             {180: [<numba.core.ir.Assign object at 0x7f0993faf2e8>],
#              216: [<numba.core.ir.Assign object at 0x7f0993fafc88>]})
# DEBUG: ==== SSA block rewrite pass on 0
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: vis = arg(0, name=vis)
# DEBUG: on stmt: weights = arg(1, name=weights)
# DEBUG: on stmt: auto_indices = arg(2, name=auto_indices)
# DEBUG: on stmt: index1 = arg(3, name=index1)
# DEBUG: on stmt: index2 = arg(4, name=index2)
# DEBUG: on stmt: out = arg(5, name=out)
# DEBUG: on stmt: divide = arg(6, name=divide)
# DEBUG: on stmt: $0.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.2 = getattr(value=$0.1, attr=empty)
# DEBUG: on stmt: $0.3 = global(len: <built-in function len>)
# DEBUG: on stmt: $0.5 = call $0.3(auto_indices, func=$0.3, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: $0.6 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $0.7 = getattr(value=$0.6, attr=float32)
# DEBUG: on stmt: $0.8 = call $0.2($0.5, $0.7, func=$0.2, args=[Var($0.5, vis_flags_weights.py:184), Var($0.7, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: auto_scale = $0.8
# DEBUG: on stmt: $const0.10 = const(NoneType, None)
# DEBUG: on stmt: $0.11 = const(int, 1)
# DEBUG: on stmt: bool26 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $26pred = call bool26($0.11, func=bool26, args=(Var($0.11, vis_flags_weights.py:185),), kws=(), vararg=None)
# DEBUG: on stmt: jump 28
# DEBUG: ==== SSA block rewrite pass on 28
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $28.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.2 = getattr(value=$28.1, attr=empty)
# DEBUG: on stmt: $28.4 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $28.5 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $28.6 = getattr(value=$28.5, attr=float32)
# DEBUG: on stmt: $28.7 = call $28.2($28.4, $28.6, func=$28.2, args=[Var($28.4, vis_flags_weights.py:185), Var($28.6, vis_flags_weights.py:185)], kws=(), vararg=None)
# DEBUG: on stmt: $phi46.1 = $28.7
# DEBUG: on stmt: jump 46
# DEBUG: ==== SSA block rewrite pass on 46
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: out.1 = $phi46.1
# DEBUG: on stmt: $46.2 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $46.3 = getattr(value=$46.2, attr=float32)
# DEBUG: on stmt: $const46.4 = const(float, 2.3283064365386963e-10)
# DEBUG: on stmt: $46.5 = call $46.3($const46.4, func=$46.3, args=[Var($const46.4, vis_flags_weights.py:186)], kws=(), vararg=None)
# DEBUG: on stmt: bad_weight = $46.5
# DEBUG: on stmt: jump 58
# DEBUG: ==== SSA block rewrite pass on 58
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 60
# DEBUG: ==== SSA block rewrite pass on 60
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $60.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $60.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const60.4 = const(int, 0)
# DEBUG: on stmt: $60.5 = static_getitem(value=$60.3, index=0, index_var=$const60.4)
# DEBUG: on stmt: $60.6 = call $60.1($60.5, func=$60.1, args=[Var($60.5, vis_flags_weights.py:187)], kws=(), vararg=None)
# DEBUG: on stmt: $60.7 = getiter(value=$60.6)
# DEBUG: on stmt: $phi74.1 = $60.7
# DEBUG: on stmt: jump 74
# DEBUG: ==== SSA block rewrite pass on 74
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $74.2 = iternext(value=$phi74.1)
# DEBUG: on stmt: $74.3 = pair_first(value=$74.2)
# DEBUG: on stmt: $74.4 = pair_second(value=$74.2)
# DEBUG: on stmt: $phi76.1 = $74.3
# DEBUG: on stmt: $phi258.1 = $74.3
# DEBUG: on stmt: $phi258.2 = $phi74.1
# DEBUG: on stmt: branch $74.4, 76, 258
# DEBUG: ==== SSA block rewrite pass on 76
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: i = $phi76.1
# DEBUG: on stmt: jump 78
# DEBUG: ==== SSA block rewrite pass on 78
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 80
# DEBUG: ==== SSA block rewrite pass on 80
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $80.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $80.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const80.4 = const(int, 1)
# DEBUG: on stmt: $80.5 = static_getitem(value=$80.3, index=1, index_var=$const80.4)
# DEBUG: on stmt: $80.6 = call $80.1($80.5, func=$80.1, args=[Var($80.5, vis_flags_weights.py:188)], kws=(), vararg=None)
# DEBUG: on stmt: $80.7 = getiter(value=$80.6)
# DEBUG: on stmt: $phi94.1 = $80.7
# DEBUG: on stmt: jump 94
# DEBUG: ==== SSA block rewrite pass on 94
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $94.2 = iternext(value=$phi94.1)
# DEBUG: on stmt: $94.3 = pair_first(value=$94.2)
# DEBUG: on stmt: $94.4 = pair_second(value=$94.2)
# DEBUG: on stmt: $phi96.1 = $94.3
# DEBUG: on stmt: $phi254.1 = $94.3
# DEBUG: on stmt: $phi254.2 = $phi94.1
# DEBUG: on stmt: branch $94.4, 96, 254
# DEBUG: ==== SSA block rewrite pass on 96
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: j = $phi96.1
# DEBUG: on stmt: jump 98
# DEBUG: ==== SSA block rewrite pass on 98
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 100
# DEBUG: ==== SSA block rewrite pass on 100
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $100.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $100.2 = global(len: <built-in function len>)
# DEBUG: on stmt: $100.4 = call $100.2(auto_indices, func=$100.2, args=[Var(auto_indices, vis_flags_weights.py:184)], kws=(), vararg=None)
# DEBUG: on stmt: $100.5 = call $100.1($100.4, func=$100.1, args=[Var($100.4, vis_flags_weights.py:189)], kws=(), vararg=None)
# DEBUG: on stmt: $100.6 = getiter(value=$100.5)
# DEBUG: on stmt: $phi112.1 = $100.6
# DEBUG: on stmt: jump 112
# DEBUG: ==== SSA block rewrite pass on 112
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $112.2 = iternext(value=$phi112.1)
# DEBUG: on stmt: $112.3 = pair_first(value=$112.2)
# DEBUG: on stmt: $112.4 = pair_second(value=$112.2)
# DEBUG: on stmt: $phi114.1 = $112.3
# DEBUG: on stmt: $phi160.1 = $112.3
# DEBUG: on stmt: $phi160.2 = $phi112.1
# DEBUG: on stmt: branch $112.4, 114, 160
# DEBUG: ==== SSA block rewrite pass on 114
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: k = $phi114.1
# DEBUG: on stmt: $114.7 = getitem(value=auto_indices, index=k)
# DEBUG: on stmt: $114.8 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var($114.7, vis_flags_weights.py:190)])
# DEBUG: on stmt: $114.9 = getitem(value=vis, index=$114.8)
# DEBUG: on stmt: $114.10 = getattr(value=$114.9, attr=real)
# DEBUG: on stmt: autocorr = $114.10
# DEBUG: on stmt: bool138 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $138pred = call bool138(divide, func=bool138, args=(Var(divide, vis_flags_weights.py:184),), kws=(), vararg=None)
# DEBUG: on stmt: branch $138pred, 140, 150
# DEBUG: ==== SSA block rewrite pass on 140
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $140.1 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $140.2 = getattr(value=$140.1, attr=reciprocal)
# DEBUG: on stmt: $140.4 = call $140.2(autocorr, func=$140.2, args=[Var(autocorr, vis_flags_weights.py:190)], kws=(), vararg=None)
# DEBUG: on stmt: $phi152.3 = $140.4
# DEBUG: on stmt: jump 152
# DEBUG: ==== SSA block rewrite pass on 150
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $phi152.3.1 = autocorr
# DEBUG: on stmt: jump 152
# DEBUG: ==== SSA block rewrite pass on 152
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $phi152.3.2 = phi(incoming_values=[Var($phi152.3, vis_flags_weights.py:191), Var($phi152.3.1, vis_flags_weights.py:191)], incoming_blocks=[140, 150])
# DEBUG: on stmt: auto_scale[k] = $phi152.3.2
# DEBUG: on stmt: jump 112
# DEBUG: ==== SSA block rewrite pass on 160
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 162
# DEBUG: ==== SSA block rewrite pass on 162
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 164
# DEBUG: ==== SSA block rewrite pass on 164
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $164.1 = global(range: <class 'range'>)
# DEBUG: on stmt: $164.3 = getattr(value=vis, attr=shape)
# DEBUG: on stmt: $const164.4 = const(int, 2)
# DEBUG: on stmt: $164.5 = static_getitem(value=$164.3, index=2, index_var=$const164.4)
# DEBUG: on stmt: $164.6 = call $164.1($164.5, func=$164.1, args=[Var($164.5, vis_flags_weights.py:192)], kws=(), vararg=None)
# DEBUG: on stmt: $164.7 = getiter(value=$164.6)
# DEBUG: on stmt: $phi178.1 = $164.7
# DEBUG: on stmt: jump 178
# DEBUG: ==== SSA block rewrite pass on 178
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $178.2 = iternext(value=$phi178.1)
# DEBUG: on stmt: $178.3 = pair_first(value=$178.2)
# DEBUG: on stmt: $178.4 = pair_second(value=$178.2)
# DEBUG: on stmt: $phi180.1 = $178.3
# DEBUG: on stmt: $phi250.1 = $178.3
# DEBUG: on stmt: $phi250.2 = $phi178.1
# DEBUG: on stmt: branch $178.4, 180, 250
# DEBUG: ==== SSA block rewrite pass on 180
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: k.1 = $phi180.1
# DEBUG: on stmt: $180.5 = getitem(value=index1, index=k.1)
# DEBUG: on stmt: $180.6 = getitem(value=auto_scale, index=$180.5)
# DEBUG: on stmt: $180.10 = getitem(value=index2, index=k.1)
# DEBUG: on stmt: $180.11 = getitem(value=auto_scale, index=$180.10)
# DEBUG: on stmt: $180.12 = $180.6 * $180.11
# DEBUG: on stmt: p = $180.12
# DEBUG: on stmt: $180.13 = global(np: <module 'numpy' from '/scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/__init__.py'>)
# DEBUG: on stmt: $180.14 = getattr(value=$180.13, attr=isfinite)
# DEBUG: on stmt: $180.16 = call $180.14(p, func=$180.14, args=[Var(p, vis_flags_weights.py:193)], kws=(), vararg=None)
# DEBUG: find_def var='p' stmt=$180.16 = call $180.14(p, func=$180.14, args=[Var(p, vis_flags_weights.py:193)], kws=(), vararg=None)
# DEBUG: on stmt: bool214 = global(bool: <class 'bool'>)
# DEBUG: on stmt: $214pred = call bool214($180.16, func=bool214, args=(Var($180.16, vis_flags_weights.py:198),), kws=(), vararg=None)
# DEBUG: on stmt: branch $214pred, 220, 216
# DEBUG: ==== SSA block rewrite pass on 216
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: p.1 = bad_weight
# DEBUG: on stmt: jump 220
# DEBUG: ==== SSA block rewrite pass on 220
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $220.6 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k.1, vis_flags_weights.py:192)])
# DEBUG: on stmt: $220.7 = getitem(value=weights, index=$220.6)
# DEBUG: on stmt: $220.8 = p * $220.7
# DEBUG: find_def var='p' stmt=$220.8 = p * $220.7
# DEBUG: find_def_from_top label 220
# DEBUG: insert phi node p.2 = phi(incoming_values=[], incoming_blocks=[]) at 220
# DEBUG: find_def_from_bottom label 216
# DEBUG: incoming_def p.1 = bad_weight
# DEBUG: find_def_from_bottom label 180
# DEBUG: incoming_def p = $180.12
# DEBUG: replaced with: $220.8 = p.2 * $220.7
# DEBUG: on stmt: $220.13 = build_tuple(items=[Var(i, vis_flags_weights.py:187), Var(j, vis_flags_weights.py:188), Var(k.1, vis_flags_weights.py:192)])
# DEBUG: on stmt: out.1[$220.13] = $220.8
# DEBUG: on stmt: jump 178
# DEBUG: ==== SSA block rewrite pass on 250
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 252
# DEBUG: ==== SSA block rewrite pass on 252
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 94
# DEBUG: ==== SSA block rewrite pass on 254
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 256
# DEBUG: ==== SSA block rewrite pass on 256
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 74
# DEBUG: ==== SSA block rewrite pass on 258
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: jump 260
# DEBUG: ==== SSA block rewrite pass on 260
# DEBUG: Running <numba.core.ssa._FixSSAVars object at 0x7f0993faf940>
# DEBUG: on stmt: $260.2 = cast(value=out.1)
# DEBUG: on stmt: return $260.2
# DEBUG: Added 'Sun' [special] (and 0 aliases)
# ===============================================================================
# Name: http://archive-gw-1.kat.ac.za:7480/1657099540/1657099540_sdp_l0.full.rdb | 1657099540-sdp-l0 (version 4.0)
# ===============================================================================
# Observer: Operator  Experiment ID: 20220706-0006
# Description: ' raster scan'
# Observed from 2022-07-06 11:25:46.519 SAST to 2022-07-06 11:36:26.640 SAST
# Dump rate / period: 0.12498 Hz / 8.002 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m047                                 2        4
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    c856M1k    1284.000         856.000           1024       835.938
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   ants=['m047']
#   spw=0
#   subarray=0
# -------------------------------------------------------------------------------
# Shape: (80 dumps, 1024 channels, 4 correlation products) => Size: 2.621 MB
# Antennas: m047  Inputs: 2  Autocorr: yes  Crosscorr: no
# Channels: 1024 (index 0 - 1023,  856.000 MHz - 1711.164 MHz), each 835.938 kHz wide
# Targets: 1 selected out of 1 in catalogue
#   ID  Name  Type      RA(J2000)     DEC(J2000)  Tags  Dumps  ModelFlux(Jy)
#    0  Sun   special             -            -           80
# Scans: 3 selected out of 3 total       Compscans: 1 selected out of 1 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   06-Jul-2022/09:25:50 - 09:29:26    0:slew     0:raster        28    0:Sun
#               09:29:34 - 09:36:14    1:scan     0:raster        51    0:Sun
#               09:36:22 - 09:36:22    2:stop     0:raster         1    0:Sun

# %%
def data_cal(file, nd_models):
    #ants = file.ants
    ants = ['m049','m058']
    receptor_serial={
    'm050':{'band':'l', 'serial':4035},
    'm058':{'band':'l', 'serial':4026}}
    pol='V'
    angle_sep = {}
    temp = {}
    for ant in range(len(ants)):
        try:
            data = scape.DataSet(file, baseline="%s" %(ants[ant]), nd_models=nd_models)
        except Exception:
            data = scape.DataSet(file, baseline="%s" % (ants[ant]), nd_models='/var/kat/katconfig/user/noise-diode-models/mkat/rx.l.%s.%s.csv'%(receptor_serial[ant]['serial'],pol.lower()))
        data = data.convert_power_to_temperature()
        data = data.select(flagkeep='~nd_on') #removing the noise diode
        data = data.select(labelkeep='scan')  #keeps the scan and remove anything at the end
        
        angle_sep[ants[ant]] = np.sqrt(np.sum((np.degrees(data.scans[0].target_coords))**2,axis=0))
        temp[ants[ant]] = data.scans[0].pol("VV").mean(axis=1)    
        
    return angle_sep, temp, data

# %%
dataset.scans[1].data

# %%
dataset.scans[0].compscan

# %%
dataset.scans[0].pointing

# %%
<scape.Scan 'slew' data=(28, 1024, 4) at 0x7f0993fcd128>
<scape.Scan 'scan' data=(51, 1024, 4) at 0x7f09954412e8>
<scape.Scan 'stop' data=(1, 1024, 4) at 0x7f0993c8acc0>
# Out:
# <function ndarray.view>

# %%
pol = 'V'
ant = rdb.ants[0]

nd_v = '/home/tmangena/jupyter_analysis/rx.l.4028.v.csv'
nd_h = '/home/tmangena/jupyter_analysis/rx.l.4028.h.csv'

dataset = scape.DataSet(rdb, baseline="%s" % (ant.name,), nd_h_model=nd_h, nd_v_model=nd_v)
print("This is type for dataset", type(dataset))
print("This is dataset", dataset)

data1 = dataset.select(flagkeep='~nd_on')
print("This is type for data1", type(data1))
print("This is data1", data1)

# data2 = data1.convert_power_to_temperature(freq_width=856.0)
# print("This is type for data2", type(data2))
# print("This is data2", data2)

dataA = dataset.scans[1].data[:,:,0]
print("This is type for dataA", type(dataA))
print("This is dataA", dataA)

dataB = data1.scans[1].data[:,:,0]
print("This is type for dataB", type(dataA))
print("This is dataB", dataA)


#print(dat)

scape.plot_compound_scan_in_time(dataset)
#plt.plot(data)
#plt.show()
# Out:
# INFO: Loading baseline 'm047,m047'
# INFO: Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# WARNING: Cannot find coupler noise diode H polarisation model for antenna m047 - using default.
# WARNING: Cannot find coupler noise diode V polarisation model for antenna m047 - using default.
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# This is type for dataset <class 'scape.dataset.DataSet'>
# This is dataset 20220706-0006 | Operator
# ' raster scan'
# antenna='m047', data_unit=counts, bands=1024, freqs=856.000000 - 1711.164062 MHz, total bw=856.000000 MHz, dumprate=0.124976 Hz
#    0: 'raster', target='Sun' [special]
#          0: 'slew', data=(28, 1024, 4), start='2022/07/06 09:25:50', az=71.1, el=33.2, path='http://archive-gw-1.kat.ac.za:7480/1657099540/1657099540_sdp_l0.full.rdb | 1657099540-sdp-l0 scan 0'
#          1: 'scan', data=(51, 1024, 4), start='2022/07/06 09:29:34', az=14.8, el=34.3, path='http://archive-gw-1.kat.ac.za:7480/1657099540/1657099540_sdp_l0.full.rdb | 1657099540-sdp-l0 scan 1'
#          2: 'stop', data=(1, 1024, 4), start='2022/07/06 09:36:22', az=5.1, el=34.5, path='http://archive-gw-1.kat.ac.za:7480/1657099540/1657099540_sdp_l0.full.rdb | 1657099540-sdp-l0 scan 2'
# This is type for data1 <class 'scape.dataset.DataSet'>
# This is data1 20220706-0006 | Operator
# ' raster scan'
# antenna='m047', data_unit=counts, bands=1024, freqs=856.000000 - 1711.164062 MHz, total bw=856.000000 MHz, dumprate=0.124976 Hz
#    0: 'raster', target='Sun' [special]
#          0: 'slew', data=(20, 1024, 4), start='2022/07/06 09:25:50', az=86.6, el=32.9, path='http://archive-gw-1.kat.ac.za:7480/1657099540/1657099540_sdp_l0.full.rdb | 1657099540-sdp-l0 scan 0'
#          1: 'scan', data=(42, 1024, 4), start='2022/07/06 09:29:34', az=16.8, el=34.3, path='http://archive-gw-1.kat.ac.za:7480/1657099540/1657099540_sdp_l0.full.rdb | 1657099540-sdp-l0 scan 1'
#          2: 'stop', data=(1, 1024, 4), start='2022/07/06 09:36:22', az=5.1, el=34.5, path='http://archive-gw-1.kat.ac.za:7480/1657099540/1657099540_sdp_l0.full.rdb | 1657099540-sdp-l0 scan 2'
# This is type for dataA <class 'numpy.ndarray'>
# This is dataA [[672.8121   101.53735  102.48747  ...  32.44926   32.033504  31.979763]
#  [672.70795  101.41218  102.33499  ...  32.632595  32.212227  32.163723]
#  [675.8016   104.63242  105.59824  ...  32.767853  32.379185  32.273533]
#  ...
#  [672.6593   102.73793  103.76257  ...  34.07093   33.64023   33.550224]
#  [673.27716  102.73417  103.751076 ...  34.085594  33.622734  33.567623]
#  [672.99316  102.713326 103.69504  ...  34.108185  33.65557   33.574944]]
# This is type for dataB <class 'numpy.ndarray'>
# This is dataB [[672.8121   101.53735  102.48747  ...  32.44926   32.033504  31.979763]
#  [672.70795  101.41218  102.33499  ...  32.632595  32.212227  32.163723]
#  [675.8016   104.63242  105.59824  ...  32.767853  32.379185  32.273533]
#  ...
#  [672.6593   102.73793  103.76257  ...  34.07093   33.64023   33.550224]
#  [673.27716  102.73417  103.751076 ...  34.085594  33.622734  33.567623]
#  [672.99316  102.713326 103.69504  ...  34.108185  33.65557   33.574944]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-292b62411c77> in <module>
#      28 #print(dat)
#      29
# ---> 30 scape.plot_compound_scan_in_time(dataset)
#      31 #plt.plot(data)
#      32 #plt.show()
#
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/scape/plots_canned.py in plot_compound_scan_in_time(compscan, pol, add_scan_ids, spike_width, band, ax)
#    1005             baseline_power = scan.baseline(scan.timestamps)
#    1006             baseline_segments.append(np.column_stack((timeline, baseline_power)))
# -> 1007         elif compscan.baseline:
#    1008             baseline_power = compscan.baseline(scan.target_coords)
#    1009             baseline_segments.append(np.column_stack((timeline, baseline_power)))
#
# AttributeError: 'DataSet' object has no attribute 'baseline'

# %%
print('baseline="%s"' % (ant.name))
# Out:
# baseline="m047"

# %%
scape.DataSet?

# %%
def modelTcal(noisefile):
    ##Read data from file
    fin = open(noisefile, 'r')
    # Read and ignore header line
    fin.readline()
    fin.readline()
    # Read model data [freq Hz, Te K]
    nd_freqs = []
    nd_temps = []
    for line in fin.readlines():
        try:
            noisemodel= numpy.array(line.strip().split(','), dtype=float)
        except: print(line.strip())
        nd_freqs.append(noisemodel[0])
        nd_temps.append(noisemodel[1])
    fin.close()
    nd_freqs = numpy.array(nd_freqs)
    nd_temps = numpy.array(nd_temps)
    return [nd_freqs, nd_temps]

    [nd_freqs, nd_temps] = modelTcal(os.path.join(nd_models,nd_file))
    Tsys = numpy.mean(nd_temps)

# %%
[nd_freqs, nd_temps] = modelTcal(nd_v)

# %%
r = rdb.select(ants=ant.name,corrprods='auto',scans='scan')
print(r)

scan_indices = rdb.scan_indices

print(scan_indices)
# Out:
# None
# [1]

# %%
rdb.select()
target = rdb.catalogue.targets[0].name
passband = rdb.channel_freqs
ants = rdb.ants
# Boltzman constant
k = 1.38e-23

for ant_idx in range(len(ants)):
    ant = ants[ant_idx]
    print('Observation data for antenna %s' % ant.name)
    
    # approximate Tsys using Tant values from model files
    nd_file=nd_h
    [nd_freqs, nd_temps] = modelTcal(noisefile)
    Tsys = numpy.mean(nd_temps)

    
    Ssys = 10.*numpy.log10(k*Tsys) + 30 # dBm/Hz
    print("Expected power spectral density of the system noise floor %.2d [dBm/Hz]" % Ssys)
    
    rdb.select()
    rdb.select(ants=ant.name,corrprods='auto',scans='scan')
    scan_indices = rdb.scan_indices
    
    for idx in range(len(scan_indices)):
        rdb.select(scans=scan_indices[idx])
        d = scape.DataSet(rdb, baseline="%s" % (ant.name,))
        if not d is None:
            d = d.select(flagkeep='~nd_on')
        data = d.scans[0].data[:,:,0]

        # power calibration scale factor
        buff_chan = len(passband)/10
        bp_floor =  (10*numpy.log10(numpy.median(numpy.abs(data), axis=0)))[int(buff_chan):-int(buff_chan)].mean()
        delta_P = bp_floor - Ssys
        
        plt.figure(2*ant_idx,figsize = (15,5))
        plt.plot(passband/1e6, 10*numpy.log10(numpy.median(numpy.abs(data), axis=0))-delta_P, label='Scan %d'%idx)       
        plt.axis('tight')
        plt.xlabel('Feq [MHz]')
        plt.ylabel('Power [dBm/ch]')
        plt.title('Observation Spectrum %s'%ant.name)
        plt.legend(loc=0)
        plt.figure(2*ant_idx+1,figsize = (15,5))
        plt.subplot(1,3,idx+1)
        plt.plot(10*numpy.log10(numpy.median(numpy.abs(data), axis=1)))
        plt.axis('tight')
        plt.xlabel('Scans [#]')
        plt.ylabel('Power [arb dBm]')
        plt.title('Observation Scans %d'%idx)
        plt.subplots_adjust(wspace=None, hspace=None)
# Out:
# Observation data for antenna m047
# Expected power spectral density of the system noise floor -185 [dBm/Hz]
# INFO: Loading baseline 'm047,m047'
# INFO: Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# WARNING: Cannot find coupler noise diode H polarisation model for antenna m047 - using default.
# WARNING: Cannot find coupler noise diode V polarisation model for antenna m047 - using default.
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0.
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# DEBUG: findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# DEBUG: findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Lato' (Lato-Thin.ttf) normal normal 200 normal>) = 10.24
# DEBUG: findfont: score(<Font 'Lato' (Lato-HairlineItalic.ttf) italic normal 100 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman17-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans' (VeraBd.ttf) normal normal 700 normal>) = 1.2440909090909091
# DEBUG: findfont: score(<Font 'Latin Modern Roman Caps' (lmromancaps10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Liberation Sans' (LiberationSans-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'FreeSerif' (FreeSerif.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Vector' (MathJax_Vector-Regular.otf) normal normal 500 normal>) = 10.145
# DEBUG: findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Schola Math' (texgyreschola-math.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_AMS' (MathJax_AMS-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans12-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant8-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'FreeSans' (FreeSans.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman12-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'FreeMono' (FreeMonoBold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'msbm10' (msbm10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans8-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'MathJax_Fraktur' (MathJax_Fraktur-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Size2' (MathJax_Size2-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'TeX Gyre Pagella Math' (texgyrepagella-math.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-Oblique.ttf) oblique normal 400 condensed>) = 1.25
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans' (Vera.ttf) normal normal 400 normal>) = 0.9590909090909092
# DEBUG: findfont: score(<Font 'Lato' (Lato-BlackItalic.ttf) italic normal 900 normal>) = 11.525
# DEBUG: findfont: score(<Font 'Latin Modern Sans Demi Cond' (lmsansdemicond10-regular.otf) normal normal 600 condensed>) = 10.44
# DEBUG: findfont: score(<Font 'Latin Modern Mono Light Cond' (lmmonoltcond10-oblique.otf) oblique normal 400 condensed>) = 11.25
# DEBUG: findfont: score(<Font 'FreeSerif' (FreeSerifItalic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Caps' (lmmonocaps10-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans Mono' (VeraMoIt.ttf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Light Cond' (lmmonoltcond10-regular.otf) normal normal 400 condensed>) = 10.25
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans' (VeraBI.ttf) oblique normal 700 normal>) = 2.244090909090909
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed.ttf) normal normal 400 condensed>) = 0.25
# DEBUG: findfont: score(<Font 'Bitstream Vera Serif' (VeraSe.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman Unslanted' (lmromanunsl10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Lato' (Lato-MediumItalic.ttf) italic normal 500 normal>) = 11.145
# DEBUG: findfont: score(<Font 'Latin Modern Mono' (lmmono12-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman7-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Liberation Sans' (LiberationSans-Italic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman7-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'MathJax_Size1' (MathJax_Size1-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Math' (latinmodern-math.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman12-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Lato' (Lato-HeavyItalic.ttf) italic normal 800 normal>) = 11.43
# DEBUG: findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans17-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans10-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman Dunhill' (lmromandunh10-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'FreeSerif' (FreeSerifBoldItalic.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans10-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Lato' (Lato-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Lato' (Lato-ThinItalic.ttf) italic normal 200 normal>) = 11.24
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-Italic.ttf) italic normal 400 condensed>) = 11.25
# DEBUG: findfont: score(<Font 'Latin Modern Roman Caps' (lmromancaps10-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'MathJax_Math' (MathJax_Math-Italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'TeX Gyre Bonum Math' (texgyrebonum-math.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'eufm10' (eufm10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Bitstream Vera Serif' (VeraSeBd.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'MathJax_Main' (MathJax_Main-Italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Bold.ttf) normal normal 700 condensed>) = 10.535
# DEBUG: findfont: score(<Font 'Lato' (Lato-Semibold.ttf) normal normal 600 normal>) = 10.24
# DEBUG: findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-BoldItalic.ttf) italic normal 700 condensed>) = 11.535
# DEBUG: findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Lato' (Lato-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'msam10' (msam10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Noto Mono' (NotoMono-Regular.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Size4' (MathJax_Size4-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Lato' (Lato-SemiboldItalic.ttf) italic normal 600 normal>) = 11.24
# DEBUG: findfont: score(<Font 'Lato' (Lato-Black.ttf) normal normal 900 normal>) = 10.525
# DEBUG: findfont: score(<Font 'stmary10' (stmary10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Liberation Mono' (LiberationMono-Italic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'FontAwesome' (FontAwesome.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman10-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman Demi' (lmromandemi10-oblique.otf) oblique normal 600 normal>) = 11.24
# DEBUG: findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'FreeSans' (FreeSansBold.ttf) normal normal 600 normal>) = 10.24
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans Mono' (VeraMono.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman9-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Liberation Mono' (LiberationMono-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Lato' (Lato-Italic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Caligraphic' (MathJax_Caligraphic-Bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant10-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'FontAwesome' (fontawesome-webfont.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman12-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman10-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'MathJax_Vector-Bold' (MathJax_Vector-Bold.otf) normal normal 500 normal>) = 10.145
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Math' (MathJax_Math-BoldItalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_WinIE6' (MathJax_WinIE6-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_SansSerif' (MathJax_SansSerif-Italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant17-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans9-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Droid Sans Fallback' (DroidSansFallbackFull.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'FreeSans' (FreeSansOblique.ttf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman9-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Lato' (Lato-Light.ttf) normal normal 300 normal>) = 10.145
# DEBUG: findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-BoldOblique.ttf) oblique normal 700 condensed>) = 1.535
# DEBUG: findfont: score(<Font 'FreeSans' (FreeSansBoldOblique.ttf) oblique normal 600 normal>) = 11.24
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman5-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Mono' (lmmono8-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman8-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans Mono' (VeraMoBI.ttf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans12-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Liberation Mono' (LiberationMono-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Mono Slanted' (lmmonoslant10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'wasy10' (wasy10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_WinChrome' (MathJax_WinChrome-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant12-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-boldoblique.otf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman7-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed.ttf) normal normal 400 condensed>) = 10.25
# DEBUG: findfont: score(<Font 'rsfs10' (rsfs10.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Mono' (lmmono10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'MathJax_SansSerif' (MathJax_SansSerif-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Main' (MathJax_Main-Bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'esint10' (esint10.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Caligraphic' (MathJax_Caligraphic-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Math' (MathJax_Math-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans10-boldoblique.otf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Liberation Sans' (LiberationSans-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Lato' (Lato-Heavy.ttf) normal normal 800 normal>) = 10.43
# DEBUG: findfont: score(<Font 'MathJax_Main' (MathJax_Main-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Liberation Serif' (LiberationSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono' (lmmono9-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Termes Math' (texgyretermes-math.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Termes' (texgyretermes-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'FreeMono' (FreeMono.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'MathJax_Script' (MathJax_Script-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Italic.ttf) italic normal 400 condensed>) = 11.25
# DEBUG: findfont: score(<Font 'Latin Modern Mono Prop' (lmmonoprop10-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'TeX Gyre Heros' (texgyreheros-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Liberation Mono' (LiberationMono-Regular.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'FreeMono' (FreeMonoOblique.ttf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans9-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans17-oblique.otf) oblique normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'MathJax_Typewriter' (MathJax_Typewriter-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman6-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'TeX Gyre Schola' (texgyreschola-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Liberation Sans Narrow' (LiberationSansNarrow-Regular.ttf) normal normal 400 condensed>) = 10.25
# DEBUG: findfont: score(<Font 'Lato' (Lato-Hairline.ttf) normal normal 100 normal>) = 10.335
# DEBUG: findfont: score(<Font 'TeX Gyre Heros Cn' (texgyreheroscn-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'MathJax_Fraktur' (MathJax_Fraktur-Bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Liberation Sans' (LiberationSans-Regular.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Liberation Serif' (LiberationSerif-Regular.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Adventor' (texgyreadventor-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Lato' (Lato-Medium.ttf) normal normal 500 normal>) = 10.145
# DEBUG: findfont: score(<Font 'Lato' (Lato-Regular.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-bolditalic.otf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'MathJax_Size3' (MathJax_Size3-Regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Math TeX Gyre' (DejaVuMathTeXGyre.ttf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Bonum' (texgyrebonum-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Mono Light' (lmmonolt10-boldoblique.otf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Mono Prop Light' (lmmonoproplt10-boldoblique.otf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman5-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman6-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman Demi' (lmromandemi10-regular.otf) normal normal 600 normal>) = 10.24
# DEBUG: findfont: score(<Font 'Latin Modern Mono Caps' (lmmonocaps10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono' (lmmono10-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Liberation Serif' (LiberationSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'TeX Gyre Chorus' (texgyrechorus-mediumitalic.otf) normal normal 500 normal>) = 10.145
# DEBUG: findfont: score(<Font 'Lato' (Lato-LightItalic.ttf) italic normal 300 normal>) = 11.145
# DEBUG: findfont: score(<Font 'Latin Modern Sans' (lmsans8-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'TeX Gyre DejaVu Math' (texgyredejavu-math.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman9-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Mono Prop' (lmmonoprop10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSans-ExtraLight.ttf) normal normal 200 normal>) = 0.24
# DEBUG: findfont: score(<Font 'FreeSerif' (FreeSerifBold.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'FreeMono' (FreeMonoBoldOblique.ttf) oblique normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'TeX Gyre Pagella' (texgyrepagella-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-BoldItalic.ttf) italic normal 700 condensed>) = 11.535
# DEBUG: findfont: score(<Font 'Latin Modern Roman Slanted' (lmromanslant9-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans Quotation' (lmsansquot8-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman10-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Liberation Serif' (LiberationSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman8-bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'DejaVu Serif' (DejaVuSerifCondensed-Bold.ttf) normal normal 700 condensed>) = 10.535
# DEBUG: findfont: score(<Font 'MathJax_SansSerif' (MathJax_SansSerif-Bold.otf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'TeX Gyre Cursor' (texgyrecursor-italic.otf) italic normal 400 normal>) = 11.05
# DEBUG: findfont: score(<Font 'Latin Modern Sans Demi Cond' (lmsansdemicond10-oblique.otf) oblique normal 600 condensed>) = 11.44
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans Mono' (VeraMoBd.ttf) normal normal 700 normal>) = 10.335
# DEBUG: findfont: score(<Font 'Latin Modern Roman Dunhill' (lmromandunh10-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'Bitstream Vera Sans' (VeraIt.ttf) oblique normal 400 normal>) = 1.9590909090909092
# DEBUG: findfont: score(<Font 'Latin Modern Roman' (lmroman8-regular.otf) normal normal 400 normal>) = 10.05
# DEBUG: findfont: score(<Font 'DejaVu Sans' (DejaVuSansCondensed-Bold.ttf) normal normal 700 condensed>) = 0.5349999999999999
# DEBUG: findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/scratch2/lkara/venv-py3/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.

# %%
passband = rdb.channel_freqs
buff_chan = len(passband)/10
print(int(buff_chan))
# Out:
# 102

# %%
dataset = scape.DataSet(rdb, baseline="%s" % (ant.name,), nd_h_model=nd_h, nd_v_model=nd_v)
d = dataset.convert_power_to_temperature(freq_width=0.0)

dat = d.select(flagkeep='~nd_on')
dat.average(channels_per_band=None)

data = dat.scans[0].data[:,:,0]

print(data)


plt.plot(data)
plt.show()
# Out:
# INFO: Loading baseline 'm047,m047'
# INFO: Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# WARNING: Cannot find coupler noise diode H polarisation model for antenna m047 - using default.
# WARNING: Cannot find coupler noise diode V polarisation model for antenna m047 - using default.
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# [[4.429173   0.70522124 0.709088   ... 2.889066   2.9882205  3.0653448 ]
#  [4.4027543  0.68192977 0.68476266 ... 2.7952583  2.8912027  2.9655662 ]
#  [4.390132   0.6672833  0.67012846 ... 2.7435493  2.8381367  2.91272   ]
#  ...
#  [4.4572067  0.68079257 0.6850143  ... 2.780587   2.8749146  2.9486225 ]
#  [4.456949   0.6808426  0.68486494 ... 2.777435   2.8694522  2.9409103 ]
#  [4.462107   0.68631065 0.6886953  ... 2.7747064  2.8683982  2.9398537 ]]
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/scape/gaincal.py:277: RuntimeWarning: invalid value encountered in true_divide
#   norm_jump = nd_delta_mu / nd_delta_sigma
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/scape/gaincal.py:489: RuntimeWarning: invalid value encountered in sqrt
#   gain_hv = np.sqrt(smooth_gain_hh * smooth_gain_vv * (smooth_delta_re_hv ** 2 + smooth_delta_im_hv ** 2))

# %%
dataset.scans[0].data?

# %%
plt.plot(np.average(dataset.scans[0], axis=(0,2)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-142-e15c22380ddd> in <module>
# ----> 1 plt.plot(np.average(dataset.scans[0], axis=(0,2)))
#       2 plt.show()
#
# <__array_function__ internals> in average(*args, **kwargs)
#
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/lib/function_base.py in average(a, axis, weights, returned)
#     378
#     379     if weights is None:
# --> 380         avg = a.mean(axis)
#     381         scl = avg.dtype.type(a.size/avg.size)
#     382     else:
#
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     145
#     146     is_float16_result = False
# --> 147     rcount = _count_reduce_items(arr, axis)
#     148     # Make this warning show up first
#     149     if rcount == 0:
#
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/numpy/core/_methods.py in _count_reduce_items(arr, axis)
#      64     items = 1
#      65     for ax in axis:
# ---> 66         items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      67     return items
#      68
#
# AxisError: axis 0 is out of bounds for array of dimension 0

# %%
import warnings

def load_cal(filename, hnd, vnd):
    """ Load the dataset into memory """
    print('Loading noise diode models')

    try:
        d = scape.DataSet(filename, nd_models=hnd)
    except IOError:
        nd = scape.gaincal.NoiseDiodeModel(freq=[1,20000],temp=[20,20])
        warnings.warn('Warning: Failed to load/find Noise Diode Models, setting models to 20K ')
        print('Warning: Failed to load/find Noise Diode Models, setting models to 20K ')
        d = scape.DataSet(filename,  nd_h_model = hnd, nd_v_model = vnd)


#     if not channel_range is None :
#         start_freq_channel = int(channel_range.split(',')[0])
#         end_freq_channel = int(channel_range.split(',')[1])
#         edge = np.tile(True, n_chan)
#         edge[slice(start_freq_channel, end_freq_channel)] = False
#     else :
#         edge = np.tile(False, n_chan)
#     #load static flags if pickle file is given
#     if len(channel_mask)>0:
#         pickle_file = open(channel_mask,mode='rb')
#         rfi_static_flags = pickle.load(pickle_file)
#         pickle_file.close()
#     else:
#         rfi_static_flags = np.tile(False, n_chan)

#     static_flags = np.logical_or(edge,rfi_static_flags)
    
#     #d = d.select(freqkeep=~static_flags)
#     freq_channel_flagged = []
#     for band in freq_channel:
#         tmp_band = []
#         for channel in band :
#             if not static_flags[channel] : # if not flagged
#                 tmp_band.append(channel)
#         #if len(tmp_band) > 0 :
#         freq_channel_flagged.append(tmp_band)

    #if not freq_channel is None :
    #    d = d.select(freqkeep=freq_channel)
    #print "Flagging RFI"
    #sd = remove_rfi(d,width=7,sigma=5)  # rfi flaging Needed ?
    print("Converting to Temperature")
    print("Plotting the number of channels in each band of the list of lists freq_channel_flagged will be useful")
    d = d.convert_power_to_temperature(freq_width=0.0)
    if not d is None:
        d = d.select(flagkeep='~nd_on')
        #d = d.select(labelkeep='track', copy=False)
        d.average(channels_per_band=None)
    return d

# %%
data_ = load_cal(rdb, nd_v, nd_h)

data1 = data_.scans[0].data[:,:,0]


plt.plot(data1)
plt.show()
# Out:
# Loading noise diode models
# INFO: Loading single-dish baseline 'm047,m047'
# INFO: Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# Warning: Failed to load/find Noise Diode Models, setting models to 20K
# INFO: Loading single-dish baseline 'm047,m047'
# INFO: Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# WARNING: Cannot find coupler noise diode H polarisation model for antenna m047 - using default.
# WARNING: Cannot find coupler noise diode V polarisation model for antenna m047 - using default.
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Warning: Failed to load/find Noise Diode Models, setting models to 20K
#   # This is added back by InteractiveShellApp.init_path()
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00000_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00768_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00512_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00000_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00032_00256_00000.npy HTTP/1.1" 200 262272
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00000_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00256_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00512_00000.npy HTTP/1.1" 200 131200
# DEBUG: http://archive-gw-1.kat.ac.za:7480 "GET /1657099540-sdp-l0/correlator_data/00064_00768_00000.npy HTTP/1.1" 200 131200
# Converting to Temperature
# Plotting the number of channels in each band of the list of lists freq_channel_flagged will be useful
# /scratch2/lkara/venv-py3/lib/python3.6/site-packages/scape/gaincal.py:277: RuntimeWarning: invalid value encountered in true_divide
#   norm_jump = nd_delta_mu / nd_delta_sigma
